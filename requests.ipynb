# %%
#here I will be testing different requests

# GET request

import requests
import json
r = requests.get("http://127.0.0.1:5000/api")
json_resp = json.loads(r.text)
json_resp
# Out:
# [{'country': 'Bulgaria',
#   'payment rate': 90.0,
#   'population 2020': 6948445,
#   'weeks paid': 58.6},
#  {'country': 'Greece',
#   'payment rate': 49.0,
#   'population 2020': 10423054,
#   'weeks paid': 43.0},
#  {'country': 'United Kingdom',
#   'payment rate': 30.0,
#   'population 2020': 67886011,
#   'weeks paid': 39.0},
#  {'country': 'Slovakia',
#   'payment rate': 75.0,
#   'population 2020': 5459642,
#   'weeks paid': 34.0},
#  {'country': 'Croatia',
#   'payment rate': 100.0,
#   'population 2020': 4105267,
#   'weeks paid': 30.0},
#  {'country': 'Czech Republic',
#   'payment rate': 61.0,
#   'population 2020': 10708981,
#   'weeks paid': 28.0},
#  {'country': 'Ireland',
#   'payment rate': 26.0,
#   'population 2020': 4937786,
#   'weeks paid': 26.0},
#  {'country': 'Hungary',
#   'payment rate': 70.0,
#   'population 2020': 9660351,
#   'weeks paid': 24.0},
#  {'country': 'Italy',
#   'payment rate': 80.0,
#   'population 2020': 60461826,
#   'weeks paid': 21.7},
#  {'country': 'Luxembourg',
#   'payment rate': 100.0,
#   'population 2020': 625978,
#   'weeks paid': 20.0},
#  {'country': 'Estonia',
#   'payment rate': 100.0,
#   'population 2020': 1326535,
#   'weeks paid': 20.0},
#  {'country': 'Poland',
#   'payment rate': 100.0,
#   'population 2020': 37846611,
#   'weeks paid': 20.0},
#  {'country': 'Malta',
#   'payment rate': 86.0,
#   'population 2020': 441543,
#   'weeks paid': 18.0},
#  {'country': 'Cyprus',
#   'payment rate': 75.0,
#   'population 2020': 1207359,
#   'weeks paid': 18.0},
#  {'country': 'Lithuania',
#   'payment rate': 100.0,
#   'population 2020': 2722289,
#   'weeks paid': 18.0},
#  {'country': 'New Zealand',
#   'payment rate': 46.0,
#   'population 2020': 4822233,
#   'weeks paid': 18.0},
#  {'country': 'Denmark',
#   'payment rate': 53.0,
#   'population 2020': 5792202,
#   'weeks paid': 18.0},
#  {'country': 'Chile',
#   'payment rate': 100.0,
#   'population 2020': 19116201,
#   'weeks paid': 18.0},
#  {'country': 'Romania',
#   'payment rate': 85.0,
#   'population 2020': 19237691,
#   'weeks paid': 18.0},
#  {'country': 'Australia',
#   'payment rate': 42.0,
#   'population 2020': 25499884,
#   'weeks paid': 18.0},
#  {'country': 'Finland',
#   'payment rate': 74.0,
#   'population 2020': 5540720,
#   'weeks paid': 17.5},
#  {'country': 'Costa Rica',
#   'payment rate': 100.0,
#   'population 2020': 5094118,
#   'weeks paid': 17.3},
#  {'country': 'Latvia',
#   'payment rate': 80.0,
#   'population 2020': 1886198,
#   'weeks paid': 16.0},
#  {'country': 'Austria',
#   'payment rate': 100.0,
#   'population 2020': 9006398,
#   'weeks paid': 16.0},
#  {'country': 'Netherlands',
#   'payment rate': 100.0,
#   'population 2020': 17134872,
#   'weeks paid': 16.0},
#  {'country': 'Canada',
#   'payment rate': 49.0,
#   'population 2020': 37742154,
#   'weeks paid': 16.0},
#  {'country': 'Spain',
#   'payment rate': 100.0,
#   'population 2020': 46754778,
#   'weeks paid': 16.0},
#  {'country': 'France',
#   'payment rate': 90.0,
#   'population 2020': 65273511,
#   'weeks paid': 16.0},
#  {'country': 'Turkey',
#   'payment rate': 66.0,
#   'population 2020': 84339067,
#   'weeks paid': 16.0},
#  {'country': 'Slovenia',
#   'payment rate': 100.0,
#   'population 2020': 2078938,
#   'weeks paid': 15.0},
#  {'country': 'Israel',
#   'payment rate': 100.0,
#   'population 2020': 8655535,
#   'weeks paid': 15.0},
#  {'country': 'Belgium',
#   'payment rate': 63.0,
#   'population 2020': 11589623,
#   'weeks paid': 15.0},
#  {'country': 'Switzerland',
#   'payment rate': 58.0,
#   'population 2020': 8654622,
#   'weeks paid': 14.0},
#  {'country': 'Germany',
#   'payment rate': 100.0,
#   'population 2020': 83783942,
#   'weeks paid': 14.0},
#  {'country': 'Japan',
#   'payment rate': 67.0,
#   'population 2020': 126476461,
#   'weeks paid': 14.0},
#  {'country': 'Iceland',
#   'payment rate': 68.0,
#   'population 2020': 341243,
#   'weeks paid': 13.0},
#  {'country': 'Norway',
#   'payment rate': 94.0,
#   'population 2020': 5421241,
#   'weeks paid': 13.0},
#  {'country': 'Sweden',
#   'payment rate': 77.0,
#   'population 2020': 10099265,
#   'weeks paid': 12.9},
#  {'country': 'South Korea',
#   'payment rate': 80.0,
#   'population 2020': 51269185,
#   'weeks paid': 12.9},
#  {'country': 'Mexico',
#   'payment rate': 100.0,
#   'population 2020': 128932753,
#   'weeks paid': 12.0},
#  {'country': 'Portugal',
#   'payment rate': 100.0,
#   'population 2020': 10196709,
#   'weeks paid': 6.0},
#  {'country': 'United States',
#   'payment rate': 0.0,
#   'population 2020': 331002651,
#   'weeks paid': 0.0}]

# %%
import requests
import json
data = {"1": "New Entry", "2": "New Entryyy",}
headers = {"Content-Type": "application/json"}
r = requests.post("http://127.0.0.1:5000/api", params=data, headers=headers) #or data=data
json_resp = json.loads(r.text)
json_resp
# Out:
# {}

# %%
# DELETE request
import requests
import json
data = {"1": "Stanislava H"}
headers = {"Content-Type": "application/json"}
r = requests.delete("http://127.0.0.1:5000/api", params=data, headers=headers)   #or d=data
json_resp = json.loads(r.text)
json_resp
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-23-f3c6e2396ced> in <module>
#       5 headers = {"Content-Type": "application/json"}
#       6 r = requests.delete("http://127.0.0.1:5000/api", params=data, headers=headers)   #or d=data
# ----> 7 json_resp = json.loads(r.text)
#       8 json_resp
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
import requests
from bs4 import BeautifulSoup

#url = 'https://worldpopulationreview.com/country-rankings/maternity-leave-by-country'  

def mat_leave(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, features="lxml")
    table = soup.find("table") 
    rows = table.find_all('tr')
    th_td_list = []
    for row in rows:
        th = row.findAll('th')
        tds = row.findAll('td')
        th_td_data_row = []
        for td in tds:
            td_text = td.text.strip()
            td_text = td_text.replace(',',"")
            if td_text == '':
                td_text = 0.0      
            else:
                td_text = td_text
            th_td_data_row.append(td_text)              
        th_td_list.append(th_td_data_row)
        th_td_list[0] = ["Country", "Weeks Paid", "Payment Rate", "Population 2020"]
    output_list = []
    for l in th_td_list[1:]:
        output_list.append([l[0],float(l[1]),float(l[2][:-1]),int(l[3])])
    #print(output_list)
    return(output_list)
    

mat_leave("https://worldpopulationreview.com/country-rankings/maternity-leave-by-country")
# Out:
# [['Bulgaria', 58.6, 90.0, 6948445],
#  ['Greece', 43.0, 49.0, 10423054],
#  ['United Kingdom', 39.0, 30.0, 67886011],
#  ['Slovakia', 34.0, 75.0, 5459642],
#  ['Croatia', 30.0, 100.0, 4105267],
#  ['Czech Republic', 28.0, 61.0, 10708981],
#  ['Ireland', 26.0, 26.0, 4937786],
#  ['Hungary', 24.0, 70.0, 9660351],
#  ['Italy', 21.7, 80.0, 60461826],
#  ['Luxembourg', 20.0, 100.0, 625978],
#  ['Estonia', 20.0, 100.0, 1326535],
#  ['Poland', 20.0, 100.0, 37846611],
#  ['Malta', 18.0, 86.0, 441543],
#  ['Cyprus', 18.0, 75.0, 1207359],
#  ['Lithuania', 18.0, 100.0, 2722289],
#  ['New Zealand', 18.0, 46.0, 4822233],
#  ['Denmark', 18.0, 53.0, 5792202],
#  ['Chile', 18.0, 100.0, 19116201],
#  ['Romania', 18.0, 85.0, 19237691],
#  ['Australia', 18.0, 42.0, 25499884],
#  ['Finland', 17.5, 74.0, 5540720],
#  ['Costa Rica', 17.3, 100.0, 5094118],
#  ['Latvia', 16.0, 80.0, 1886198],
#  ['Austria', 16.0, 100.0, 9006398],
#  ['Netherlands', 16.0, 100.0, 17134872],
#  ['Canada', 16.0, 49.0, 37742154],
#  ['Spain', 16.0, 100.0, 46754778],
#  ['France', 16.0, 90.0, 65273511],
#  ['Turkey', 16.0, 66.0, 84339067],
#  ['Slovenia', 15.0, 100.0, 2078938],
#  ['Israel', 15.0, 100.0, 8655535],
#  ['Belgium', 15.0, 63.0, 11589623],
#  ['Switzerland', 14.0, 58.0, 8654622],
#  ['Germany', 14.0, 100.0, 83783942],
#  ['Japan', 14.0, 67.0, 126476461],
#  ['Iceland', 13.0, 68.0, 341243],
#  ['Norway', 13.0, 94.0, 5421241],
#  ['Sweden', 12.9, 77.0, 10099265],
#  ['South Korea', 12.9, 80.0, 51269185],
#  ['Mexico', 12.0, 100.0, 128932753],
#  ['Portugal', 6.0, 100.0, 10196709],
#  ['United States', 0.0, 0.0, 331002651]]

# %%
a = mat_leave("https://worldpopulationreview.com/country-rankings/maternity-leave-by-country")

# %%
for row in a:
    print(row)
# Out:
# ['Bulgaria', 58.6, 90.0, 6948445]
# ['Greece', 43.0, 49.0, 10423054]
# ['United Kingdom', 39.0, 30.0, 67886011]
# ['Slovakia', 34.0, 75.0, 5459642]
# ['Croatia', 30.0, 100.0, 4105267]
# ['Czech Republic', 28.0, 61.0, 10708981]
# ['Ireland', 26.0, 26.0, 4937786]
# ['Hungary', 24.0, 70.0, 9660351]
# ['Italy', 21.7, 80.0, 60461826]
# ['Luxembourg', 20.0, 100.0, 625978]
# ['Estonia', 20.0, 100.0, 1326535]
# ['Poland', 20.0, 100.0, 37846611]
# ['Malta', 18.0, 86.0, 441543]
# ['Cyprus', 18.0, 75.0, 1207359]
# ['Lithuania', 18.0, 100.0, 2722289]
# ['New Zealand', 18.0, 46.0, 4822233]
# ['Denmark', 18.0, 53.0, 5792202]
# ['Chile', 18.0, 100.0, 19116201]
# ['Romania', 18.0, 85.0, 19237691]
# ['Australia', 18.0, 42.0, 25499884]
# ['Finland', 17.5, 74.0, 5540720]
# ['Costa Rica', 17.3, 100.0, 5094118]
# ['Latvia', 16.0, 80.0, 1886198]
# ['Austria', 16.0, 100.0, 9006398]
# ['Netherlands', 16.0, 100.0, 17134872]
# ['Canada', 16.0, 49.0, 37742154]
# ['Spain', 16.0, 100.0, 46754778]
# ['France', 16.0, 90.0, 65273511]
# ['Turkey', 16.0, 66.0, 84339067]
# ['Slovenia', 15.0, 100.0, 2078938]
# ['Israel', 15.0, 100.0, 8655535]
# ['Belgium', 15.0, 63.0, 11589623]
# ['Switzerland', 14.0, 58.0, 8654622]
# ['Germany', 14.0, 100.0, 83783942]
# ['Japan', 14.0, 67.0, 126476461]
# ['Iceland', 13.0, 68.0, 341243]
# ['Norway', 13.0, 94.0, 5421241]
# ['Sweden', 12.9, 77.0, 10099265]
# ['South Korea', 12.9, 80.0, 51269185]
# ['Mexico', 12.0, 100.0, 128932753]
# ['Portugal', 6.0, 100.0, 10196709]
# ['United States', 0.0, 0.0, 331002651]
